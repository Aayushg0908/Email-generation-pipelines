# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.3 is available.
# You should consider upgrading via the 'c:\Users\tanma\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
import pandas as pd

# %%
df= pd.read_csv("E:\Synthetic-Email-Generation-tool-main\interview_confirmation\interview_confirmation.csv")

# %%
df.info()
df.head()
# df['label'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       600 non-null    int64
#  1   subject  600 non-null    object
#  2   body     600 non-null    object
#  3   tone     600 non-null    object
#  4   intent   600 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 23.6+ KB
#    id                                            subject  \
# 0   1  Interview Confirmation | Customer Support Agen...
# 1   2    Interview Confirmation | Urban Planner Position
# 2   3    Interview Confirmation | Web Developer Position
# 3   4     Interview Confirmation | Phlebotomist Position
# 4   5  Bartender Interview Confirmation | The Red Lio...
#
#                                                 body  \
# 0  Dear Julianne Reed,\n\nThank you for confirmin...
# 1  Dear Sophia Patel,\n\nThank you for confirming...
# ...
